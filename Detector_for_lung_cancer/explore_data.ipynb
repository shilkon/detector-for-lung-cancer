# %%
# %matplotlib inline
import numpy as np

# %%
from src.dsets import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=False)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %%
print(len(positiveInfo_list))
print(positiveInfo_list[0])
# Out:
# 1351
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0  32.3 mm
#  100  17.7 mm
#  200  13.0 mm
#  300  10.0 mm
#  400   8.2 mm
#  500   7.0 mm
#  600   6.3 mm
#  700   5.7 mm
#  800   5.1 mm
#  900   4.7 mm
# 1000   4.0 mm
# 1100   0.0 mm
# 1200   0.0 mm
# 1300   0.0 mm

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)
    
for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(47.90350511, 37.60442008, -99.93417567))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(44.19, 37.79, -107.01))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(40.69, 32.19, -97.15))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.44242293, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311', center_xyz=(-45.29440163, 74.86925386, -97.52812481))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.07544345, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156', center_xyz=(-102.571208, -5.186558766, -205.1033412))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(121.152909372, 12.9136003304, -159.399497186))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(118.8539408, 11.54202797, -165.5042458))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.87269662, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.177086402277715068525592995222', center_xyz=(-66.628286875, 57.151972075, -110.12035075))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.41540526, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219618492426142913407827034169', center_xyz=(-101.7504204, -95.65460516, -138.4943211))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.107109359065300889765026303943', center_xyz=(-100.57, -66.23, -218.76))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920626694402549886949', center_xyz=(-71.09, 68.3, -160.4))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(106.18, 12.61, -96.81))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(96.2846726653, 19.0348690723, -88.478440818))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 190.84, -516.82))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 143.23, -427.1))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(85.12, 152.33, -425.7))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(8.8, 174.74, -401.87))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(5.99, 171.94, -398.37))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(1.79, 166.34, -408.88))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))

# %%
np.histogram(diameter_list)
# Out:
# (array([323, 466, 248, 111,  71,  57,  37,  29,   5,   4]),
#  array([ 0.        ,  3.22700302,  6.45400605,  9.68100907, 12.9080121 ,
#         16.13501512, 19.36201815, 22.58902117, 25.8160242 , 29.04302722,
#         32.27003025]))

# %%
from src.vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2025-04-13 22:14:35,877 INFO     pid:17216 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x0000011253BEC050>: 551065 training samples, 549714 neg, 1351 pos, unbalanced ratio
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.47644347, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.397522780537301776672854630421', center_xyz=(17.9378195346, 205.22918595, -53.3354710007))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.186704876, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.229096941293122177107846044795', center_xyz=(-68.17, -70.0, -195.16))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.651470635, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860', center_xyz=(-128.94, -175.04, -297.87))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.194632613233275988184244485809', center_xyz=(-49.4039029019, -5.5318192577, -88.9963083535))
# 4 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.615286406, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.183843376225716802567192412456', center_xyz=(25.4388043952, -16.2079478353, -116.245016287))
# 5 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.106805338, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.338875090785618956575597613546', center_xyz=(-102.47, -47.01, -174.36))
# 6 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.20083329, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.208737629504245244513001631764', center_xyz=(-76.4016874491, -49.8714752896, -93.5889886634))
# 7 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.533837123, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478', center_xyz=(-73.81, -50.67, -258.89))
# 8 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.239358021703233250639913775427', center_xyz=(56.4, 86.52, -182.88))
# 9 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.37870953, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219349715895470349269596532320', center_xyz=(-69.5192880631, 18.1987685533, -200.166411786))
# 10 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.452780772, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.338875090785618956575597613546', center_xyz=(-116.938637163, 45.9049059756, -257.038464599))
# 11 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.252634638822000832774167856951', center_xyz=(57.6196645822, 62.1950267294, -103.584513692))
# 12 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.253443196, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.151764021165118974848436095034', center_xyz=(-65.13, 103.47, -619.94))
# 13 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.985106486, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.233001470265230594739708503198', center_xyz=(-63.46, -59.87, -191.84))
# 14 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.734742324, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.367204840301639918160517361062', center_xyz=(-88.0626283087, 62.887393491, -105.773461671))
# 15 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.270390050141765094612147226290', center_xyz=(114.23, -39.57, -159.14))
# 16 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.182192086929819295877506541021', center_xyz=(39.07, 106.58, -70.82))
# 17 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600', center_xyz=(104.55, 22.07, -224.52))
# 18 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.43827943, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.882070241245008756731854510592', center_xyz=(133.246898241, 16.7070552054, -129.759076857))
# 19 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.234851716, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.310395752124284049604069960014', center_xyz=(-93.0906611371, 11.5867546452, -126.745974668))
# 20 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-86.9514169487, 162.142965995, -455.060669104))
# 21 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.097459329, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.199975006921901879512837687266', center_xyz=(53.5674911033, -20.774356725, -51.2391306415))
# 22 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.59997723, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.311476128731958142981941696518', center_xyz=(-89.13201967, 231.21132665, -614.5556829))
# 23 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.436398619, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219428004988664846407984058588', center_xyz=(127.41, 44.72, -188.9))
# 24 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.720379813, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556', center_xyz=(88.49, -68.29, -148.06))
# 25 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.98553245, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.255999614855292116767517149228', center_xyz=(-113.630770578, -13.5780158854, -172.306126103))
# 26 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.286217539434358186648717203667', center_xyz=(-63.6616093198, 26.5048449832, -62.7695162007))
# 27 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121108220866971173712229588402', center_xyz=(-86.83, -53.39, -128.52))
# 28 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.10334672, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.199670099218798685977406484591', center_xyz=(73.53, 21.86, -217.93))
# 29 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.070646904, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.249450003033735700817635168066', center_xyz=(-108.72, -127.92, -247.86))
# 30 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.897380231, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.557875302364105947813979213632', center_xyz=(-42.94020698, 58.676448865, -185.3394925))
# 31 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.963386128, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600', center_xyz=(96.15, 38.88, -207.65))
# 32 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.053719722, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-84.3086034783, -42.2047464888, -146.649587983))
# 33 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.81977981, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.204566802718283633558802774757', center_xyz=(55.8946900158, 33.2506192722, -61.0856459632))
# 34 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.78152704, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487745546557477250336016826588', center_xyz=(52.18, -21.02, -81.16))
# 35 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.162972621, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950', center_xyz=(-91.2889907452, -6.79332126973, -218.642696739))
# 36 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.239358021703233250639913775427', center_xyz=(-54.99, -19.97, -169.49))
# 37 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.841667885, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.214252223927572015414741039150', center_xyz=(115.705836253, 36.4857189567, -142.797261031))
# 38 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.138813197521718693188313387015', center_xyz=(53.64, 71.87, -252.01))
# 39 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.989971578, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202283133206014258077705539227', center_xyz=(31.9706538157, 58.0384449421, -116.138508269))
# 40 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.84107821, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.338114620394879648539943280992', center_xyz=(-77.89748032, 22.32739599, -184.9089456))
# 41 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.503203598, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.294120933998772507043263238704', center_xyz=(-130.0836445, 28.107140945, -209.38790945))
# 42 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.61583872, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.174907798609768549012640380786', center_xyz=(-37.7502593522, -64.8611502182, -123.842950065))
# 43 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.87074364, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.332829333783605240302521201463', center_xyz=(-2.1, 45.07, -163.13))
# 44 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.387576729, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121824995088859376862458155637', center_xyz=(63.68, -130.41, -124.33))
# 45 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.937590395, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.315214756157389122376518747372', center_xyz=(50.4, -30.48, -40.82))
# 46 CandidateInfoTuple(isNodule_bool=True, diameter_mm=24.77327957, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268', center_xyz=(96.9273129009, -25.9394823208, -259.572637924))
# 47 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.418972326, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.312704771348460502013249647868', center_xyz=(103.71, 110.47, -170.44))
# 48 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.570090698, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.262736997975960398949912434623', center_xyz=(-100.86, -126.12, -178.63))
# 49 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.110678335949765929063942738609', center_xyz=(-38.05, -102.13, -136.99))
# 50 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300136985030081433029390459071', center_xyz=(110.56, 3.39, -224.48))
# 51 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.940547015, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.162901839201654862079549658100', center_xyz=(78.2051627124, -69.2957475474, -219.606089847))
# 52 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.09125367, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.295420274214095686326263147663', center_xyz=(-65.9640510945, 81.2984155672, -179.11789495))
# 53 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.617203255, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154703816225841204080664115280', center_xyz=(-60.19, 95.2, -215.4))
# 54 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.413884666, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.275755514659958628040305922764', center_xyz=(-47.937124415, -257.16863575, -250.27544235))
# 55 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.002203924, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.212346425055214308006918165305', center_xyz=(70.049643485, 71.529264965, -222.46044205))
# 56 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.515646762, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.323753921818102744511069914832', center_xyz=(87.028496338, 30.0176170213, -267.025672395))
# 57 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.642186103, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478', center_xyz=(33.42, -101.14, -87.68))
# 58 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.96263215, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(53.8710070042, 139.156354144, -625.795207073))
# 59 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.174907798609768549012640380786', center_xyz=(-32.2873969916, -65.9666903894, -127.27979693))
# 60 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.970428941353693253759289796610', center_xyz=(-107.92, 72.82, -133.53))
# 61 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.304621719, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188059920088313909273628445208', center_xyz=(-110.13, 85.01, 1507.01))
# 62 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.109990357, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.199282854229880908602362094937', center_xyz=(-48.0, -63.56, -191.04))
# 63 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.246461343, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.832260670372728970918746541371', center_xyz=(23.2, 36.79, -85.53))
# 64 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.700892679, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.592821488053137951302246128864', center_xyz=(70.0680773121, -130.555000108, -81.4648388148))
# 65 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.133378195429627807109985347209', center_xyz=(-35.64297562, 51.569715785, -250.4701115))
# 66 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.834016122, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.774060103415303828812229821954', center_xyz=(89.096201616, 10.9418336942, -124.882649725))
# 67 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487745546557477250336016826588', center_xyz=(46.57, -14.01, -71.3))
# 68 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.391787919, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.200841000324240313648595016964', center_xyz=(-108.3235972, 69.84600267, -107.0754822))
# 69 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.934589046, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.264251211689085893915477907261', center_xyz=(-50.96, 45.64, -110.91))
# 70 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.220611088, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.118140393257625250121502185026', center_xyz=(-164.0885883, -136.62101885, -300.73316025))
# 71 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.868316403, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.224465398054769500989828256685', center_xyz=(13.94, 215.55, -790.0))
# 72 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.129168997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.217754016294471278921686508169', center_xyz=(-118.54, 124.69, -567.86))
# 73 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.983754092, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757', center_xyz=(111.87, 136.44, -527.15))
# 74 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.15074869, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.135657246677982059395844827629', center_xyz=(-108.80596115, -124.79818415, -105.3502955))
# 75 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.902097585, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.328789598898469177563438457842', center_xyz=(94.9190748948, -58.5406751141, -222.631875087))
# 76 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.587295623, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.162718361851587451505896742103', center_xyz=(-26.4309803057, -91.5141781646, -201.131626823))
# 77 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.513023675145166449943177283490', center_xyz=(99.82, 52.19, -78.15))
# 78 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.261700367741314729940340271960', center_xyz=(21.02, 2.8, -89.14))
# 79 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.65708157, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.247816269490470394602288565775', center_xyz=(29.52910529, 114.1085871, -401.6675011))
# 80 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.62904955, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534006575256943390479252771547', center_xyz=(58.1090454962, -23.8769340894, -69.490632328))
# 81 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.285669845, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.252697338970999211181671881792', center_xyz=(-84.06, 81.63, -149.9))
# 82 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.128059459, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.461155505515403114280165935891', center_xyz=(-94.803813769, 29.3190303542, -207.706558041))
# 83 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.462472935, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.443400977949406454649939526179', center_xyz=(46.2, 229.7, -310.45))
# 84 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.955440317, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.329404588567903628160652715124', center_xyz=(29.78, 60.6, -277.95))
# 85 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.05940652, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843', center_xyz=(88.4711209658, 32.9338043994, -78.2315830223))
# 86 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292', center_xyz=(90.22, 37.39, -128.88))
# 87 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.253917448, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.305858704835252413616501469037', center_xyz=(22.744456585, 196.0703828, -367.29208485))
# 88 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.675543413149938600000570588203', center_xyz=(109.84858565, -112.867182443, -211.564380061))
# 89 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.519376862, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.113679818447732724990336702075', center_xyz=(90.8643364916, 74.8250561561, -199.759017499))
# 90 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.16781391, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.747803439040091794717626507402', center_xyz=(61.0485406091, -6.48185765539, -134.96276234))
# 91 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.973944221, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227796349777753378641347819780', center_xyz=(144.39, -136.07, -435.19))
# 92 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.127950372, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734', center_xyz=(-8.81, 58.85, -109.84))
# 93 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.882070241245008756731854510592', center_xyz=(93.8081969818, -18.0635687538, -122.702027977))
# 94 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.85837472, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.128059192202504367870633619224', center_xyz=(87.35, 16.81, -273.11))
# 95 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.896326902, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.257383535269991165447822992959', center_xyz=(-43.299453715, 80.0138405506, -115.004713586))
# 96 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.208342207, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.333145094436144085379032922488', center_xyz=(-36.68, 95.21, -230.94))
# 97 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.907212712, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129982010889624423230394257528', center_xyz=(-15.07, 50.81, -137.18))
# 98 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.290135156874098366424871975734', center_xyz=(-54.2291295443, 89.2064998147, -214.680882561))
# 99 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.283782817, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534006575256943390479252771547', center_xyz=(125.05, -9.15, -208.18))

# %%
# %matplotlib inline
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2025-04-13 22:14:36,003 INFO     pid:17216 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x000001125593ECF0>: 390 training samples, 387 neg, 3 pos, unbalanced ratio
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.252634638822000832774167856951 166 False [166, 306, 389]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2025-04-13 22:14:40,198 INFO     pid:17216 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x0000011259C378F0>: 1061 training samples, 1060 neg, 1 pos, unbalanced ratio
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 126 False [126]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2025-04-13 22:14:44,126 INFO     pid:17216 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x000001125A310710>: 605 training samples, 604 neg, 1 pos, unbalanced ratio
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354 317 False [317]

# %%
LunaDataset()[0]
# Out:
# 2025-04-13 22:14:51,160 INFO     pid:17216 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x000001125B7C2EA0>: 551065 training samples, 549714 neg, 1351 pos, unbalanced ratio
# (tensor([[[[-793., -787., -776.,  ..., -659., -504., -506.],
#            [-787., -789., -795.,  ..., -676., -508., -456.],
#            [-813., -806., -792.,  ..., -659., -441., -329.],
#            ...,
#            [ 369.,  290.,  233.,  ..., -505., -519., -536.],
#            [ 357.,  359.,  307.,  ..., -529., -533., -537.],
#            [ 164.,  259.,  293.,  ..., -501., -494., -487.]],
#
#           [[-800., -797., -789.,  ..., -468., -263., -215.],
#            [-798., -796., -801.,  ..., -503., -254., -146.],
#            [-814., -812., -811.,  ..., -487., -208.,  -82.],
#            ...,
#            [ 407.,  286.,  219.,  ..., -560., -594., -604.],
#            [ 459.,  408.,  311.,  ..., -605., -614., -619.],
#            [ 235.,  320.,  334.,  ..., -568., -577., -570.]],
#
#           [[-810., -808., -800.,  ..., -269.,  -57.,    4.],
#            [-803., -804., -812.,  ..., -360.,  -92.,   13.],
#            [-816., -830., -843.,  ..., -404., -124.,  -25.],
#            ...,
#            [ 424.,  273.,  202.,  ..., -568., -609., -613.],
#            [ 557.,  460.,  325.,  ..., -663., -691., -687.],
#            [ 353.,  428.,  400.,  ..., -634., -679., -669.]],
#
#           ...,
#
#           [[-815., -819., -832.,  ..., -509., -623., -709.],
#            [-759., -789., -826.,  ..., -719., -744., -733.],
#            [-801., -799., -805.,  ..., -820., -816., -794.],
#            ...,
#            [ -42.,  -13.,    2.,  ..., -571., -587., -581.],
#            [ -78.,  -41.,  -14.,  ..., -503., -514., -510.],
#            [ -81.,  -64.,  -41.,  ..., -234., -223., -201.]],
#
#           [[-819., -815., -808.,  ..., -638., -617., -630.],
#            [-784., -787., -792.,  ..., -766., -717., -678.],
#            [-817., -793., -773.,  ..., -817., -795., -766.],
#            ...,
#            [ -32.,   -9.,    2.,  ..., -582., -600., -618.],
#            [ -89.,  -57.,  -18.,  ..., -535., -541., -539.],
#            [-114., -109.,  -73.,  ..., -253., -227., -196.]],
#
#           [[-831., -830., -823.,  ..., -755., -705., -674.],
#            [-822., -817., -812.,  ..., -790., -749., -713.],
#            [-853., -838., -810.,  ..., -800., -789., -776.],
#            ...,
#            [ -24.,   -2.,   12.,  ..., -598., -612., -609.],
#            [-102.,  -74.,  -13.,  ..., -524., -528., -515.],
#            [-132., -131.,  -71.,  ..., -225., -190., -150.]]]]),
#  tensor([1, 0]),
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.325164338773720548739146851679',
#  tensor([248, 394, 122]))

# %%
import numpy as np
import ipyvolume as ipv
V = np.zeros((128,128,128)) # our 3d array
# outer box
V[30:-30,30:-30,30:-30] = 0.75
V[35:-35,35:-35,35:-35] = 0.0
# inner box
V[50:-50,50:-50,50:-50] = 0.25
V[55:-55,55:-55,55:-55] = 0.0
ipv.quickvolshow(V, level=[0.25, 0.75], opacity=0.03, level_width=0.1, data_min=0, data_max=1)
# Out:
# c:\Users\ilyas\MedicalNN\detector-for-lung-cancer\.venv\Lib\site-packages\ipyvolume\serialize.py:102: RuntimeWarning: invalid value encountered in cast
#   subdata[..., i] = ((gradient[i][zindex] / 2.0 + 0.5) * 255).astype(np.uint8)
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %%
ct = getCt(series_uid)
ipv.quickvolshow(ct.hu_a, level=[0.25, 0.5, 0.9], opacity=0.1, level_width=0.1, data_min=-1000, data_max=1000)
# Out:
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %% [markdown]
# # Note: the following visualization doesn't look very good.
# It's only included here for completeness.

# %%
import scipy.ndimage.morphology
def build2dLungMask(ct, mask_ndx, threshold_gcc = 0.7):
    dense_mask = ct.hu_a[mask_ndx] > threshold_gcc
    denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
    tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
    body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
    air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)

    lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask


def build3dLungMask(ct):
    air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = mask_list = \
        [np.zeros_like(ct.hu_a, dtype=np.bool_) for _ in range(6)]

    for mask_ndx in range(ct.hu_a.shape[0]):
        for i, mask_ary in enumerate(build2dLungMask(ct, mask_ndx)):
            mask_list[i][mask_ndx] = mask_ary

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask

# %%
from src.dsets import getCt
ct = getCt(series_uid)
air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = build3dLungMask(ct)
# Out:
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_17216\3318691767.py:4: DeprecationWarning: Please import `binary_closing` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_17216\3318691767.py:5: DeprecationWarning: Please import `binary_opening` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_17216\3318691767.py:6: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_17216\3318691767.py:7: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_17216\3318691767.py:9: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

# %%
bones = ct.hu_a * (ct.hu_a > 1.5)
lungs = ct.hu_a * air_mask
ipv.figure()
ipv.pylab.volshow(bones + lungs, level=[0.17, 0.17, 0.23], data_min=100, data_max=900)
ipv.show()
# Out:
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.17, max=1.0, ste…

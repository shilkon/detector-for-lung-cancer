# %%
# %matplotlib inline
import numpy as np

# %%
from src.dsets import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=False)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %%
print(len(positiveInfo_list))
print(positiveInfo_list[0])
# Out:
# 1351
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0  32.3 mm
#  100  17.7 mm
#  200  13.0 mm
#  300  10.0 mm
#  400   8.2 mm
#  500   7.0 mm
#  600   6.3 mm
#  700   5.7 mm
#  800   5.1 mm
#  900   4.7 mm
# 1000   4.0 mm
# 1100   0.0 mm
# 1200   0.0 mm
# 1300   0.0 mm

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)
    
for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(47.90350511, 37.60442008, -99.93417567))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(44.19, 37.79, -107.01))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(40.69, 32.19, -97.15))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.44242293, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311', center_xyz=(-45.29440163, 74.86925386, -97.52812481))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.07544345, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156', center_xyz=(-102.571208, -5.186558766, -205.1033412))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(121.152909372, 12.9136003304, -159.399497186))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(118.8539408, 11.54202797, -165.5042458))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.87269662, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.177086402277715068525592995222', center_xyz=(-66.628286875, 57.151972075, -110.12035075))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.41540526, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219618492426142913407827034169', center_xyz=(-101.7504204, -95.65460516, -138.4943211))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.107109359065300889765026303943', center_xyz=(-100.57, -66.23, -218.76))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920626694402549886949', center_xyz=(-71.09, 68.3, -160.4))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(106.18, 12.61, -96.81))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(96.2846726653, 19.0348690723, -88.478440818))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 190.84, -516.82))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 143.23, -427.1))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(85.12, 152.33, -425.7))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(8.8, 174.74, -401.87))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(5.99, 171.94, -398.37))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(1.79, 166.34, -408.88))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))

# %%
np.histogram(diameter_list)
# Out:
# (array([323, 466, 248, 111,  71,  57,  37,  29,   5,   4], dtype=int64),
#  array([ 0.        ,  3.22700302,  6.45400605,  9.68100907, 12.9080121 ,
#         16.13501512, 19.36201815, 22.58902117, 25.8160242 , 29.04302722,
#         32.27003025]))

# %%
from src.vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2024-05-31 22:24:30,499 INFO     pid:8520 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x00000191C098FBB0>: 551065 training samples, 549714 neg, 1351 pos, unbalanced ratio
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.168737928729363683423228050295', center_xyz=(-50.9152715265, 103.526056192, -119.750333501))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.779556482, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(99.534526984, -25.0008193614, -199.759483337))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.272123398257168239653655006815', center_xyz=(100.89, 0.0, -186.63))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.858789829, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556', center_xyz=(79.38, -114.51, -74.45))
# 4 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.181004159, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.200725988589959521302320481687', center_xyz=(90.1717956, -97.698850455, -169.28036015))
# 5 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.174907798609768549012640380786', center_xyz=(-32.2873969916, -65.9666903894, -127.27979693))
# 6 CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.48525426, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-57.04638761, 131.2249427, -520.247305))
# 7 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.153985109349433321657655488650', center_xyz=(-37.02, 42.35, -59.82))
# 8 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750', center_xyz=(59.55, -35.39, -218.96))
# 9 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.217955041973656886482758642958', center_xyz=(-49.97, 56.49, -48.64))
# 10 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.80179732, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230', center_xyz=(-57.857957645, 73.54809899, -146.7640884))
# 11 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.174837024, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124822907934319930841506266464', center_xyz=(-60.44, -73.47, -230.69))
# 12 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.611381537, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.195557219224169985110295082004', center_xyz=(-64.93, -1.51, -154.2))
# 13 CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.99864751, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.290135156874098366424871975734', center_xyz=(-58.9822830798, 92.211052775, -217.824186038))
# 14 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.225740939, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.326057189095429101398977448288', center_xyz=(-32.45, -165.13, -79.85))
# 15 CandidateInfoTuple(isNodule_bool=True, diameter_mm=24.78201705, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.183982839679953938397312236359', center_xyz=(-46.36896147, 64.20509868, -149.8345695))
# 16 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.275766318636944297772360944907', center_xyz=(-75.22, -42.71, -143.99))
# 17 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.584711922, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.226152078193253087875725735761', center_xyz=(-88.61304756, 252.25331995, -541.59130525))
# 18 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.1269398, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.592821488053137951302246128864', center_xyz=(111.5941127, -132.77451915, -178.014486))
# 19 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.6270362, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.206028343897359374907954580114', center_xyz=(-70.3630295409, -69.1427683417, -165.660421886))
# 20 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.357746933, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-100.11, 179.7, -498.43))
# 21 CandidateInfoTuple(isNodule_bool=True, diameter_mm=23.68811013, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.194766721609772924944646251928', center_xyz=(-110.51142385, 8.69531556, -123.28560915))
# 22 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.272123398257168239653655006815', center_xyz=(127.52, 30.83, -221.85))
# 23 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.133374031, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129007566048223160327836686225', center_xyz=(44.7466561625, 100.502919218, -138.960951794))
# 24 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.204802250386343794613980417281', center_xyz=(104.78, -145.47, -166.42))
# 25 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.053693982, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.994459772950022352718462251777', center_xyz=(-161.33, -29.09, -269.29))
# 26 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.251215764736737018371915284679', center_xyz=(-87.9425069047, -40.7313304499, -274.540460786))
# 27 CandidateInfoTuple(isNodule_bool=True, diameter_mm=19.34841823, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.198698492013538481395497694975', center_xyz=(82.81, -15.75, -162.89))
# 28 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.194045747, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121824995088859376862458155637', center_xyz=(-103.66, -156.32, -144.0))
# 29 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.143261683, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(-23.271057745, 193.19472445, -391.33523255))
# 30 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.36232088, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028192176989979435275', center_xyz=(82.74160967, 54.99915946, -150.26926585))
# 31 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.88873794, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.117040183261056772902616195387', center_xyz=(55.223452955, 190.42190725, -579.21014875))
# 32 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.25825997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-86.23791683, 16.037327905, -70.24667756))
# 33 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.784886899, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(96.5080202269, 213.298021661, -613.21058414))
# 34 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-78.2266125547, 180.542140994, -467.88476912))
# 35 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.65179825, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.257515388956260258681136624817', center_xyz=(-42.76026562, -131.3943052, -226.1148729))
# 36 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.162972621, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950', center_xyz=(-91.2889907452, -6.79332126973, -218.642696739))
# 37 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.963289468, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951', center_xyz=(-89.0622258691, 200.659242189, -729.62003874))
# 38 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.554327379, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.195557219224169985110295082004', center_xyz=(114.731991661, 39.537983524, -76.5968159383))
# 39 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.88143912, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.208737629504245244513001631764', center_xyz=(97.67643527, 37.77078568, -70.32903988))
# 40 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.211051626197585058967163339846', center_xyz=(36.84, -163.92, -125.64))
# 41 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.21739005, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.640729228179368154416184318668', center_xyz=(-113.17, -225.85, -199.99))
# 42 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.851190527, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.148229375703208214308676934766', center_xyz=(74.03, -152.65, -178.59))
# 43 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.693203437, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.397522780537301776672854630421', center_xyz=(-86.7787063642, 217.648644835, -220.53523377))
# 44 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.318099839, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.162351539386551708034407968929', center_xyz=(115.33, -174.23, -161.8))
# 45 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.321935195060268166151738328001', center_xyz=(-46.62, 90.1, -177.7))
# 46 CandidateInfoTuple(isNodule_bool=True, diameter_mm=23.04344837, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.329404588567903628160652715124', center_xyz=(37.5974516166, -29.0404354588, -89.5895072532))
# 47 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.514315903, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.243094273518213382155770295147', center_xyz=(87.3226743515, 81.1630952287, -234.60047741))
# 48 CandidateInfoTuple(isNodule_bool=True, diameter_mm=20.52475616, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.198698492013538481395497694975', center_xyz=(67.1465716505, 69.5146890415, -217.556904881))
# 49 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.061649841, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.946129570505893110165820050204', center_xyz=(122.72655386, -68.3441869639, -158.422191995))
# 50 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.20481203, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292', center_xyz=(38.34262343, 76.25022792, -216.8597756))
# 51 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(5.99, 171.94, -398.37))
# 52 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.054585195, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124822907934319930841506266464', center_xyz=(74.73, -76.1, -262.19))
# 53 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.746983627, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.267519732763035023633235877753', center_xyz=(-90.42, -88.14, -174.99))
# 54 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.47561299, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.169128136262002764211589185953', center_xyz=(54.4462360178, 10.0927486763, -36.7112190437))
# 55 CandidateInfoTuple(isNodule_bool=True, diameter_mm=16.09508736, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551', center_xyz=(98.9776983169, 15.2227351415, -106.527415396))
# 56 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.13322034, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121391737347333465796214915391', center_xyz=(51.27, -67.3, -117.57))
# 57 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600', center_xyz=(104.55, 22.07, -224.52))
# 58 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.30912384, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.725023183844147505748475581290', center_xyz=(-64.9498295957, 212.532831249, -494.687042539))
# 59 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.421061711, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805', center_xyz=(36.438695755, 270.0152618, -690.4074981))
# 60 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.133378195429627807109985347209', center_xyz=(-35.64297562, 51.569715785, -250.4701115))
# 61 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.833712029, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.167661207884826429102690781600', center_xyz=(38.3002139131, -130.341053688, -199.274850478))
# 62 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.661547445, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.169128136262002764211589185953', center_xyz=(126.839261128, 21.2728781494, -131.165846156))
# 63 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.000997888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.119806527488108718706404165837', center_xyz=(-78.89, -95.35, -168.74))
# 64 CandidateInfoTuple(isNodule_bool=True, diameter_mm=24.77327957, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268', center_xyz=(97.3540746077, -16.7922286632, -263.659908373))
# 65 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.319450365, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.955688628308192728558382581802', center_xyz=(56.41, 250.36, -517.19))
# 66 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478', center_xyz=(110.53, -121.46, -237.84))
# 67 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.128059459, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.461155505515403114280165935891', center_xyz=(-94.803813769, 29.3190303542, -207.706558041))
# 68 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(36.54, 78.1, -122.92))
# 69 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.498132148, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.147250707071097813243473865421', center_xyz=(-9.99855338357, 96.4954361664, -115.434543081))
# 70 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630', center_xyz=(7.51, -21.89, -88.76))
# 71 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551', center_xyz=(111.623717138, -3.54834778761, -200.992016436))
# 72 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.484694873, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.569096986145782511000054443951', center_xyz=(-47.14, -64.05, -63.12))
# 73 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300136985030081433029390459071', center_xyz=(113.36, 16.7, -226.59))
# 74 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-82.01161135, 186.5539408, -467.9168457))
# 75 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.803987517543436570820681016103', center_xyz=(-64.05, -240.16, -232.79))
# 76 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.77961842, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478', center_xyz=(106.735462, -126.2609139, -246.7420448))
# 77 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.501806204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.258220324170977900491673635112', center_xyz=(95.24, 1.76, -126.87))
# 78 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.034133192, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.315770913282450940389971401304', center_xyz=(56.69, 87.85, -175.47))
# 79 CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.86783511, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.323408652979949774528873200770', center_xyz=(70.8255923438, 27.9653840377, -101.655301073))
# 80 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.436398619, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219428004988664846407984058588', center_xyz=(127.41, 44.72, -188.9))
# 81 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.90241061, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.324290109423920971676288828329', center_xyz=(-106.68, -230.31, -197.0))
# 82 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.44804609, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.258220324170977900491673635112', center_xyz=(65.269885947, 77.1139672909, -225.983630121))
# 83 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.341588419, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.229860476925100292554329427970', center_xyz=(-108.35, -70.73, -137.4))
# 84 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.158102396, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.268030488196493755113553009785', center_xyz=(73.0866692697, 69.8394247919, -36.2852098322))
# 85 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.0575593, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.301462380687644451483231621986', center_xyz=(92.0769690736, -138.616865958, 1159.37108493))
# 86 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.402746921, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134370886216012873213579659366', center_xyz=(-58.34, -97.56, -227.54))
# 87 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.199653232, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.792381786708289670758399079830', center_xyz=(109.75, 155.36, -445.59))
# 88 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.15074869, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.135657246677982059395844827629', center_xyz=(-108.80596115, -124.79818415, -105.3502955))
# 89 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.898838135, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972', center_xyz=(113.830468964, 66.0461521594, -243.919370312))
# 90 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.744966449, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.179162671133894061547290922949', center_xyz=(-128.04, 111.67, -740.09))
# 91 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.07596577, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137773550852881583165286615668', center_xyz=(56.91700616, -191.249701, 181.7328981))
# 92 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.562175963, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.162845309248822193437735868939', center_xyz=(17.080365225, -80.84149346, -182.4485856))
# 93 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.429381085, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.244442540088515471945035689377', center_xyz=(73.67, -119.7, -208.89))
# 94 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.279300249795483097365868125932', center_xyz=(45.7331986181, 13.6870567945, -84.8975922579))
# 95 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.073504253, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.254957696184671649675053562027', center_xyz=(95.25, -130.6, -139.32))
# 96 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.670798042, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.908250781706513856628130123235', center_xyz=(-62.04, 92.13, -213.2))
# 97 CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.67293211, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.226383054119800793308721198594', center_xyz=(-90.4620156282, 194.076543394, -638.349785566))
# 98 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.39203287, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.195557219224169985110295082004', center_xyz=(99.6221439719, 42.6500463024, -141.906395565))
# 99 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.489388614, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.229096941293122177107846044795', center_xyz=(-74.48, -215.79, -182.5))

# %%
# %matplotlib inline
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2024-05-31 22:24:30,630 INFO     pid:8520 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x00000191C0A624D0>: 473 training samples, 468 neg, 5 pos, unbalanced ratio
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124822907934319930841506266464 54 False [54, 55, 130, 176, 394]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2024-05-31 22:24:38,469 INFO     pid:8520 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x00000191C3104820>: 1061 training samples, 1060 neg, 1 pos, unbalanced ratio
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 724 False [724]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2024-05-31 22:24:43,515 INFO     pid:8520 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x00000191C78DB640>: 605 training samples, 604 neg, 1 pos, unbalanced ratio
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354 368 False [368]

# %%
LunaDataset()[0]
# Out:
# 2024-05-31 22:24:55,666 INFO     pid:8520 src.dsets:269:__init__ <src.dsets.LunaDataset object at 0x00000191C3043850>: 551065 training samples, 549714 neg, 1351 pos, unbalanced ratio
# (tensor([[[[-599., -530., -555.,  ..., -844., -799., -804.],
#            [-745., -586., -501.,  ..., -770., -699., -694.],
#            [-772., -630., -556.,  ..., -831., -783., -742.],
#            ...,
#            [-736., -722., -743.,  ..., -761., -792., -802.],
#            [-755., -774., -788.,  ..., -751., -784., -800.],
#            [-802., -791., -782.,  ..., -811., -812., -816.]],
#
#           [[-677., -562., -431.,  ..., -848., -830., -777.],
#            [-862., -715., -469.,  ..., -831., -811., -728.],
#            [-693., -566., -436.,  ..., -884., -831., -778.],
#            ...,
#            [-681., -713., -740.,  ..., -837., -843., -815.],
#            [-651., -692., -732.,  ..., -818., -827., -782.],
#            [-728., -731., -732.,  ..., -798., -796., -769.]],
#
#           [[-656., -638., -515.,  ..., -830., -866., -868.],
#            [-767., -815., -724.,  ..., -843., -870., -831.],
#            [-657., -725., -698.,  ..., -880., -817., -739.],
#            ...,
#            [-704., -742., -768.,  ..., -823., -819., -835.],
#            [-653., -710., -759.,  ..., -829., -853., -831.],
#            [-673., -718., -755.,  ..., -805., -811., -804.]],
#
#           ...,
#
#           [[-797., -806., -796.,  ...,   29.,   31.,   56.],
#            [-803., -799., -799.,  ...,   22.,   30.,   39.],
#            [-827., -821., -840.,  ...,   39.,   56.,   53.],
#            ...,
#            [-797., -805., -790.,  ..., -805., -797., -779.],
#            [-807., -822., -805.,  ..., -835., -834., -829.],
#            [-800., -820., -818.,  ..., -862., -817., -795.]],
#
#           [[-823., -798., -780.,  ...,   24.,    4.,   39.],
#            [-800., -807., -791.,  ...,   10.,  -17.,    6.],
#            [-822., -821., -763.,  ...,   22.,   37.,   12.],
#            ...,
#            [-832., -851., -821.,  ..., -809., -832., -815.],
#            [-819., -816., -761.,  ..., -858., -844., -806.],
#            [-854., -796., -757.,  ..., -836., -814., -842.]],
#
#           [[-771., -764., -752.,  ...,   31.,   28.,   71.],
#            [-773., -798., -772.,  ...,    7.,   -4.,   46.],
#            [-804., -817., -746.,  ...,    9.,   40.,   59.],
#            ...,
#            [-840., -836., -832.,  ..., -824., -849., -835.],
#            [-856., -854., -845.,  ..., -855., -851., -803.],
#            [-857., -843., -824.,  ..., -847., -850., -812.]]]]),
#  tensor([1, 0]),
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.174692377730646477496286081479',
#  tensor([ 80, 298, 161]))

# %%
import numpy as np
import ipyvolume as ipv
V = np.zeros((128,128,128)) # our 3d array
# outer box
V[30:-30,30:-30,30:-30] = 0.75
V[35:-35,35:-35,35:-35] = 0.0
# inner box
V[50:-50,50:-50,50:-50] = 0.25
V[55:-55,55:-55,55:-55] = 0.0
ipv.quickvolshow(V, level=[0.25, 0.75], opacity=0.03, level_width=0.1, data_min=0, data_max=1)
# Out:
# c:\Users\ilyas\AppData\Local\Programs\Python\Python310\lib\site-packages\ipyvolume\serialize.py:102: RuntimeWarning: invalid value encountered in cast
#   subdata[..., i] = ((gradient[i][zindex] / 2.0 + 0.5) * 255).astype(np.uint8)
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %%
ct = getCt(series_uid)
ipv.quickvolshow(ct.hu_a, level=[0.25, 0.5, 0.9], opacity=0.1, level_width=0.1, data_min=-1000, data_max=1000)
# Out:
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %% [markdown]
# # Note: the following visualization doesn't look very good.
# It's only included here for completeness.

# %%
import scipy.ndimage.morphology
def build2dLungMask(ct, mask_ndx, threshold_gcc = 0.7):
    dense_mask = ct.hu_a[mask_ndx] > threshold_gcc
    denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
    tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
    body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
    air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)

    lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask


def build3dLungMask(ct):
    air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = mask_list = \
        [np.zeros_like(ct.hu_a, dtype=np.bool_) for _ in range(6)]

    for mask_ndx in range(ct.hu_a.shape[0]):
        for i, mask_ary in enumerate(build2dLungMask(ct, mask_ndx)):
            mask_list[i][mask_ndx] = mask_ary

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask

# %%
from src.dsets import getCt
ct = getCt(series_uid)
air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = build3dLungMask(ct)
# Out:
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_8520\3318691767.py:4: DeprecationWarning: Please import `binary_closing` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_8520\3318691767.py:5: DeprecationWarning: Please import `binary_opening` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_8520\3318691767.py:6: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_8520\3318691767.py:7: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)
# C:\Users\ilyas\AppData\Local\Temp\ipykernel_8520\3318691767.py:9: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

# %%
bones = ct.hu_a * (ct.hu_a > 1.5)
lungs = ct.hu_a * air_mask
ipv.figure()
ipv.pylab.volshow(bones + lungs, level=[0.17, 0.17, 0.23], data_min=100, data_max=900)
ipv.show()
# Out:
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.17, max=1.0, ste…
